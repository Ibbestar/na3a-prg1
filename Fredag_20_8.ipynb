# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibbestar/na3a-prg1/blob/main/Fredag_20_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.formatters import SVGFormatter
print("Jag älskar programmering")
print("Varför älskar du det?")
print("För noll 0ch ett är mina två favorit siffror")
print("vad är din favorit färg då?")
Färg = input("Färg")
print("snygg färg")
# Out:
# Jag älskar programmering
# Varför älskar du det?
# För noll 0ch ett är mina två favorit siffror
# vad är din favorit färg då?
# Färgblå
# snygg färg
# 675
