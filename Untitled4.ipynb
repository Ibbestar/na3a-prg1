# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibbestar/na3a-prg1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

datorns_tal = random.randint(1, 1000)
print("Jag tänker på ett nummer mellan 1 och 1000.")

antal_försök = 10
korrekt_gissat = False

for försök_nr in range(1, antal_försök + 1):
  fråga = int(input(f"Försök {försök_nr}/{antal_försök}: Vilket tal tror du datorn tänker på? "))

  if fråga == datorns_tal:
    print(f"Grattis din gissning är helt korrekt! Du gissade rätt på {försök_nr} försök.")
    korrekt_gissat = True

  if fråga < datorns_tal:
    print(f"Kom igen nu kungen, Högre än {fråga} kan du!")
  else:
    print(f"Ojoj vad stort du gick, lägre än {fråga} kan du nog!")

if not korrekt_gissat:
  print(f"Tyvärr, du tog slut på försök. Det rätta talet var {datorns_tal}.")
# Out:
# Jag tänker på ett nummer mellan 1 och 1000.
# Försök 1/10: Vilket tal tror du datorn tänker på? 10
# Kom igen nu kungen, Högre än 10 kan du!
# Försök 2/10: Vilket tal tror du datorn tänker på? 100
# Kom igen nu kungen, Högre än 100 kan du!
# Försök 3/10: Vilket tal tror du datorn tänker på? 300
# Kom igen nu kungen, Högre än 300 kan du!
# Försök 4/10: Vilket tal tror du datorn tänker på? 400
# Kom igen nu kungen, Högre än 400 kan du!
# Försök 5/10: Vilket tal tror du datorn tänker på? 500
# Kom igen nu kungen, Högre än 500 kan du!
# Försök 6/10: Vilket tal tror du datorn tänker på? 600
# Kom igen nu kungen, Högre än 600 kan du!
# Försök 7/10: Vilket tal tror du datorn tänker på? 800
# Kom igen nu kungen, Högre än 800 kan du!
# Försök 8/10: Vilket tal tror du datorn tänker på? 900
# Kom igen nu kungen, Högre än 900 kan du!
# Försök 9/10: Vilket tal tror du datorn tänker på? 999
# Ojoj vad stort du gick, lägre än 999 kan du nog!
# Försök 10/10: Vilket tal tror du datorn tänker på? 946
# Ojoj vad stort du gick, lägre än 946 kan du nog!
# Tyvärr, du tog slut på försök. Det rätta talet var 928.
