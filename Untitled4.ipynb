# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibbestar/na3a-prg1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

datorns_tal = random.randint(1, 1000)
print("Jag tänker på ett nummer mellan 1 och 1000.")

antal_försök = 10
korrekt_gissat = False

for försök_nr in range(1, antal_försök + 1):
  fråga = int(input(f"Försök {försök_nr}/{antal_försök}: Vilket tal tror du datorn tänker på? "))

  if fråga == datorns_tal:
    print(f"Grattis din gissning är helt korrekt! Du gissade rätt på {försök_nr} försök.")
    korrekt_gissat = True


  if fråga < datorns_tal:
    print(f"Kom igen nu kungen, Högre än {fråga} kan du!")
  else:
    print(f"Ojoj vad stort du gick, lägre än {fråga} kan du nog!")

if not korrekt_gissat:
  print(f"Tyvärr, du tog slut på försök. Det rätta talet var {datorns_tal}.")
# Out:
# Jag tänker på ett nummer mellan 1 och 1000.
# Försök 1/10: Vilket tal tror du datorn tänker på? 345
# Ojoj vad stort du gick, lägre än 345 kan du nog!
# Försök 2/10: Vilket tal tror du datorn tänker på? 100
# Ojoj vad stort du gick, lägre än 100 kan du nog!
# Försök 3/10: Vilket tal tror du datorn tänker på? 50
# Kom igen nu kungen, Högre än 50 kan du!
# Försök 4/10: Vilket tal tror du datorn tänker på? 75
# Ojoj vad stort du gick, lägre än 75 kan du nog!
# Försök 5/10: Vilket tal tror du datorn tänker på? 65
# Ojoj vad stort du gick, lägre än 65 kan du nog!
# Försök 6/10: Vilket tal tror du datorn tänker på? 55
# Kom igen nu kungen, Högre än 55 kan du!
# Försök 7/10: Vilket tal tror du datorn tänker på? 57
# Kom igen nu kungen, Högre än 57 kan du!
# Försök 8/10: Vilket tal tror du datorn tänker på? 60
# Kom igen nu kungen, Högre än 60 kan du!
# Försök 9/10: Vilket tal tror du datorn tänker på? 63
# Ojoj vad stort du gick, lägre än 63 kan du nog!
# Försök 10/10: Vilket tal tror du datorn tänker på? 61
# Grattis din gissning är helt korrekt! Du gissade rätt på 10 försök.
# Ojoj vad stort du gick, lägre än 61 kan du nog!
