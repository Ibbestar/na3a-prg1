# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibbestar/na3a-prg1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

tal = random.randint(1, 10)
fråga = int(input("Vilket tal tror du datorn tänker på?"))

if fråga == tal:
  print("Grattis rätt gissning sir")

else:
  print("Du gissade tyvärr fel")

  print(f"Du gissade på {fråga} men svaret var {tal}")
# Out:
# Vilket tal tror du datorn tänker på?6
# Du gissade tyvärr fel
# Du gissade på 6 men svaret var 10
