# %% [markdown]
# <a href="https://colab.research.google.com/github/Ibbestar/na3a-prg1/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Alex_applen_pris = 7
Petra_päron_pris = 13

Antal_applen_Alex_1 = 1
Antal_päron_Petra_1 = 1

summa_1 = Alex_applen_pris * Antal_applen_Alex_1
summa_2 = Petra_päron_pris * Antal_päron_Petra_1

if summa_1 > summa_2:
  print("Alex vinner")

elif summa_1 < summa_2:
  print("Petra vinner")

else:
  print("Det blev lika")

Antal_applen_Alex_2 = 13
Antal_päron_Petra_2 = 7

summa_3 = Alex_applen_pris * Antal_applen_Alex_2
summa_4 = Petra_päron_pris * Antal_päron_Petra_2

if summa_3 > summa_4:
  print("Alex vinner")

elif summa_3 < summa_4:
  print("Petra vinner")

else:
  print("Det blev lika")

Antal_applen_Alex_3 = 15
Antal_päron_Petra_3 = 8

summa_5 = Alex_applen_pris * Antal_applen_Alex_3
summa_6 = Petra_päron_pris * Antal_päron_Petra_3

if summa_5 > summa_6:
  print("Alex vinner")

elif summa_5 < summa_6:
  print("Petra vinner")

else:
  print("Det blev lika")
# Out:
# Petra vinner
# Det blev lika
# Alex vinner
